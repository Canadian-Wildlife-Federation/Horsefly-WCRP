# %% [markdown]
# # Strategies & Actions
#
# Table 10. Effectiveness evaluation of identified conservation strategies and associated actions to improve connectivity for target species in the Horsefly River watershed. The planning team identified five broad strategies to implement through this WCRP, 1) crossing remediation, 2) lateral barrier remediation, 3) dam remediation, 4) barrier prevention, and 5) communication and education. Individual actions were qualitatively evaluated based on the anticipated effect each action will have on realizing on-the-ground gains in connectivity. Effectiveness ratings are based on a combination of "Feasibility and "Impact", Feasibility is defined as the degree to which the project team can implement the action within realistic constraints (financial, time, ethical, etc.) and Impact is the degree to which the action is likely to contribute to achieving one or more of the goals established in this plan.
#
# Strategy 1: Crossing Remediation

# %%
import numpy as np
from IPython.display import display
import pandas as pd

data = pd.read_csv('tables\Strategy1.csv', index_col=False)

def fix_table(val):
    return str(val)

def highlighttab7(val):
    red = '#ff0000;'
    yellow = '#ffff00;'
    lgreen = '#92d050;'
    dgreen = '#03853e;'

    if val=="Medium" or val=="Need more information": color = yellow
    elif val=="Very high" or val=="Very effective" : color = lgreen
    elif val =="High" or val=="Effective": color = dgreen
    else: color = 'white'
    return 'background-color: %s' % color

data = data.replace(np.nan, '', regex=True)

data = data.applymap(fix_table)

data.style.applymap(highlighttab7).hide_index()
# Out:
# <style  type="text/css" >
# #T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow0_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow0_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow0_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow1_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow1_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow1_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow1_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow1_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow1_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow2_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow2_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow2_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow2_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow2_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow2_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow3_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow3_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow3_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow3_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow3_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow3_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow4_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow4_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow4_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow4_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow4_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow4_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow5_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow5_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow5_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow5_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow5_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow5_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow6_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow6_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow6_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow6_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow6_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow6_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow7_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow7_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow7_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow7_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow7_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow7_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow8_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow8_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow8_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow8_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow8_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow8_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow9_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow9_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow9_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow9_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow9_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow9_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow10_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow10_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow10_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow10_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow10_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow10_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow11_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow11_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow11_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow12_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow12_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow12_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow13_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow13_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow13_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow14_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow14_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow14_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow15_col0,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow15_col1,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow15_col2,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow15_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow15_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow15_col5,#T_dc03 ...
#             background-color:  white;
#         }#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow0_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow0_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow11_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow11_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow13_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow13_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow17_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow17_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow17_col5{
#             background-color:  #03853e;
#         }#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow0_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow11_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow12_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow12_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow12_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow13_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow14_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow14_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow14_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow16_col3,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow16_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow16_col5,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow18_col3{
#             background-color:  #92d050;
#         }#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow18_col4,#T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow18_col5{
#             background-color:  #ffff00;
#         }</style><table id="T_dc037de2_1fed_11ed_b6f8_b445066bfd9b" ><thead>    <tr>        <th class="col_heading level0 col0" >ID</th>        <th class="col_heading level0 col1" >Actions</th>        <th class="col_heading level0 col2" >Details</th>        <th class="col_heading level0 col3" >Feasibility</th>        <th class="col_heading level0 col4" >Impact</th>        <th class="col_heading level0 col5" >Effectiveness</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_dc037de2_1fed_11ed_b6f8_b445066bfd9brow0_col0" class="data row0 col0" >1.1</td>
#                         <td id="T_dc037de2_1fed

# %% [markdown]
# Strategy 2: Lateral Barrier Remediation

# %%
data = pd.read_csv('tables\Strategy2.csv', index_col=False)

data = data.replace(np.nan, '', regex=True)

data = data.applymap(fix_table)

data.style.applymap(highlighttab7).hide_index()
# Out:
# <style  type="text/css" >
# #T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col0,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col1,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col2,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col0,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col1,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col2,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col0,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col1,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col2,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col0,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col1,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col2,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col3,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col4,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col5,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col0,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col1,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col2,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col3,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col4,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col5,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col0,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col1,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col2,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col3,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col4,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col5,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow6_col0,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow6_col1,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow6_col2,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow7_col0,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow7_col1,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow7_col2{
#             background-color:  white;
#         }#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col3,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col5{
#             background-color:  #03853e;
#         }#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col4,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col3,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col4,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col5,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col3,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col4,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col5,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow6_col3,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow6_col4,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow6_col5,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow7_col3,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow7_col4,#T_dc0ca490_1fed_11ed_b806_b445066bfd9brow7_col5{
#             background-color:  #92d050;
#         }</style><table id="T_dc0ca490_1fed_11ed_b806_b445066bfd9b" ><thead>    <tr>        <th class="col_heading level0 col0" >ID</th>        <th class="col_heading level0 col1" >Actions</th>        <th class="col_heading level0 col2" >Details</th>        <th class="col_heading level0 col3" >Feasibility</th>        <th class="col_heading level0 col4" >Impact</th>        <th class="col_heading level0 col5" >Effectiveness</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col0" class="data row0 col0" >2.1</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col1" class="data row0 col1" >Remediate dikes / berms / other lateral barriers</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col2" class="data row0 col2" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col3" class="data row0 col3" >High</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col4" class="data row0 col4" >Very high</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow0_col5" class="data row0 col5" >Effective</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col0" class="data row1 col0" >2.2</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col1" class="data row1 col1" >Initiate a barrier owner outreach program</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col2" class="data row1 col2" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col3" class="data row1 col3" >Very high</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col4" class="data row1 col4" >Very high</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow1_col5" class="data row1 col5" >Very effective</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col0" class="data row2 col0" >2.3</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col1" class="data row2 col1" >Knowledge Gap: Identify and map year-round lateral habitat, as well as overwintering habitat</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col2" class="data row2 col2" >Explore the use of a drone to identify lateral habitat.</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col3" class="data row2 col3" >Very high</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col4" class="data row2 col4" >Very high</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow2_col5" class="data row2 col5" >Very effective</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col0" class="data row3 col0" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col1" class="data row3 col1" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col2" class="data row3 col2" >CNFASAR proposal:</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col3" class="data row3 col3" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col4" class="data row3 col4" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow3_col5" class="data row3 col5" ></td>
#             </tr>
#             <tr>
#                                 <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col0" class="data row4 col0" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col1" class="data row4 col1" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col2" class="data row4 col2" >- Volunteers from the HRR will conduct field habitat assessments following modules in the Pacific Streamkeepers Handbook to assess disconnected lateral and overwintering salmon habitats in the Horsefly watershed</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col3" class="data row4 col3" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col4" class="data row4 col4" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow4_col5" class="data row4 col5" ></td>
#             </tr>
#             <tr>
#                                 <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col0" class="data row5 col0" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col1" class="data row5 col1" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col2" class="data row5 col2" >-Funding for equipment in 2022-2023, and for field transportation in 2022-2023, 2023-2024</td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col3" class="data row5 col3" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col4" class="data row5 col4" ></td>
#                         <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow5_col5" class="data row5 col5" ></td>
#             </tr>
#             <tr>
#                                 <td id="T_dc0ca490_1fed_11ed_b806_b445066bfd9brow6_col0" class="data row6

# %% [markdown]
# Strategy 3: Dam Remediation

# %%
data = pd.read_csv('tables\Strategy3.csv', index_col=False)

data = data.replace(np.nan, '', regex=True)

data = data.applymap(fix_table)

data.style.applymap(highlighttab7).hide_index()
# Out:
# <style  type="text/css" >
# #T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col0,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col1,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col2,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col0,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col1,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col2,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col0,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col1,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col2,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col0,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col1,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col2,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col0,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col1,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col2,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col0,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col1,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col2{
#             background-color:  white;
#         }#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col3,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col5,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col3,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col5,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col4,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col5{
#             background-color:  #ffff00;
#         }#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col4,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col3,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col3,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col3,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col4,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col5{
#             background-color:  #92d050;
#         }#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col4,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col3,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col4,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col5,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col4,#T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col5{
#             background-color:  #03853e;
#         }</style><table id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9b" ><thead>    <tr>        <th class="col_heading level0 col0" >ID</th>        <th class="col_heading level0 col1" >Actions</th>        <th class="col_heading level0 col2" >Details</th>        <th class="col_heading level0 col3" >Feasibility</th>        <th class="col_heading level0 col4" >Impact</th>        <th class="col_heading level0 col5" >Effectiveness</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col0" class="data row0 col0" >3.1</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col1" class="data row0 col1" >Remediate Dams</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col2" class="data row0 col2" ></td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col3" class="data row0 col3" >Medium</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col4" class="data row0 col4" >Very high</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow0_col5" class="data row0 col5" >Need more information</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col0" class="data row1 col0" >3.2</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col1" class="data row1 col1" >Install Fish Passage</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col2" class="data row1 col2" ></td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col3" class="data row1 col3" >Medium</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col4" class="data row1 col4" >High</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow1_col5" class="data row1 col5" >Need more information</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col0" class="data row2 col0" >3.3</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col1" class="data row2 col1" >Connect with Cattleman's Association to explore a partnership to remediate dams</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col2" class="data row2 col2" >This may involve exploring alternative water management actions that would allow for the remediation of irrigation dams.</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col3" class="data row2 col3" >High</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col4" class="data row2 col4" >Medium</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow2_col5" class="data row2 col5" >Need more information</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col0" class="data row3 col0" >3.4</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col1" class="data row3 col1" >Knowledge Gap: Continue updating the barrier prioritization model</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col2" class="data row3 col2" >The model has been updated to reflect 2021 field assessments and intermediate barrier review.</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col3" class="data row3 col3" >Very high</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col4" class="data row3 col4" >High</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow3_col5" class="data row3 col5" >Effective</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col0" class="data row4 col0" >3.5</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col1" class="data row4 col1" >Knowledge Gap: Assess dams to determine whether they exist and are truly blocking fish habitat</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col2" class="data row4 col2" >Four dams were assessed during 2021 field season; additional field assessment needed.</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col3" class="data row4 col3" >Very high</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col4" class="data row4 col4" >High</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow4_col5" class="data row4 col5" >Effective</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col0" class="data row5 col0" >3.6</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col1" class="data row5 col1" >Knowledge Gap: Identify and map dam ownership</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col2" class="data row5 col2" ></td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col3" class="data row5 col3" >Very high</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col4" class="data row5 col4" >Very high</td>
#                         <td id="T_dc0fb982_1fed_11ed_bd88_b445066bfd9brow5_col5" class="data row5 col5" >Very effective</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Strategy 4: Barrier Prevention

# %%
import pandas as pd

data = pd.read_csv('tables\Strategy4.csv', index_col=False)




data = data.applymap(fix_table)

data.style.applymap(highlighttab7).hide_index()

#display(data)
# Out:
# <style  type="text/css" >
# #T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col0,#T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col1,#T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col2,#T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col0,#T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col1,#T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col2{
#             background-color:  white;
#         }#T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col3,#T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col3{
#             background-color:  #92d050;
#         }#T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col4,#T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col5{
#             background-color:  #03853e;
#         }#T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col4,#T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col5{
#             background-color:  #ffff00;
#         }</style><table id="T_dc12ca14_1fed_11ed_9888_b445066bfd9b" ><thead>    <tr>        <th class="col_heading level0 col0" >ID</th>        <th class="col_heading level0 col1" >Actions</th>        <th class="col_heading level0 col2" >Details</th>        <th class="col_heading level0 col3" >Feasibility</th>        <th class="col_heading level0 col4" >Impact</th>        <th class="col_heading level0 col5" >Effectiveness</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col0" class="data row0 col0" >4.1</td>
#                         <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col1" class="data row0 col1" >Explore potential partnerships with industrial companies</td>
#                         <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col2" class="data row0 col2" >Invite industrial players to a workshop on how to apply crossing / lateral barrier BMPs. BMPs could include those that minimize the need for road-stream crossings.</td>
#                         <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col3" class="data row0 col3" >Very high</td>
#                         <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col4" class="data row0 col4" >High</td>
#                         <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow0_col5" class="data row0 col5" >Effective</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col0" class="data row1 col0" >4.2</td>
#                         <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col1" class="data row1 col1" >Stabilize sediment sources that are explicitly linked to sediment wedges or erosion that are acting as barriers</td>
#                         <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col2" class="data row1 col2" >This could include numerous bank stabilization techniques, including restoring riparian vegetation. This applies to some tributaries that have altered confluence areas - the link needs to be made between confluence alterations and timing of movement for juvenile fish. Local ranchers and Cattleman's association could be engaged, as well as forestry licensees.</td>
#                         <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col3" class="data row1 col3" >Very high</td>
#                         <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col4" class="data row1 col4" >Medium</td>
#                         <td id="T_dc12ca14_1fed_11ed_9888_b445066bfd9brow1_col5" class="data row1 col5" >Need more information</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Strategy 5: Communication and Education

# %%
data = pd.read_csv('tables\Strategy5.csv', index_col=False)

data = data.replace(np.nan, '', regex=True)

data = data.applymap(fix_table)

data.style.applymap(highlighttab7).hide_index()
# Out:
# <style  type="text/css" >
# #T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow0_col0,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow0_col1,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow0_col2,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow1_col0,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow1_col1,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow1_col2,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow2_col0,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow2_col1,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow2_col2,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow3_col0,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow3_col1,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow3_col2,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow4_col0,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow4_col1,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow4_col2,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow5_col0,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow5_col1,#T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow5_col2{
#             background-color:  white;
#         }</style><table id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9b" ><thead>    <tr>        <th class="col_heading level0 col0" >ID</th>        <th class="col_heading level0 col1" >Actions</th>        <th class="col_heading level0 col2" >Details</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow0_col0" class="data row0 col0" >5.1</td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow0_col1" class="data row0 col1" >Implement the WCRP Progress Tracking Plan</td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow0_col2" class="data row0 col2" >The WCRP Progress Tracking Plan will help the team determine if we are achieving our goals and objectives.</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow1_col0" class="data row1 col0" >5.2</td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow1_col1" class="data row1 col1" >Develop a communication strategy to raise awareness and support for this WCRP</td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow1_col2" class="data row1 col2" >This intervention includes communicating both the WCRP and the collaborative process in developing it, as well as communicating outcomes (e.g., barrier remediations).</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow2_col0" class="data row2 col0" ></td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow2_col1" class="data row2 col1" ></td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow2_col2" class="data row2 col2" >CNFASAR proposal:</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow3_col0" class="data row3 col0" ></td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow3_col1" class="data row3 col1" ></td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow3_col2" class="data row3 col2" >- HRR will work with CWF to develop outreach and communications materials, including press releases, social media content, a video, and content for their website</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow4_col0" class="data row4 col0" ></td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow4_col1" class="data row4 col1" ></td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow4_col2" class="data row4 col2" >- With HRR, CWF will present on fish passage issues and solutions at the annual Horsefly River Salmon Festival</td>
#             </tr>
#             <tr>
#                                 <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow5_col0" class="data row5 col0" ></td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow5_col1" class="data row5 col1" ></td>
#                         <td id="T_dc170ca4_1fed_11ed_8ce0_b445066bfd9brow5_col2" class="data row5 col2" ></td>
#             </tr>
#     </tbody></table>
