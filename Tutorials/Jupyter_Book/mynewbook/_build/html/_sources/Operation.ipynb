# %% [markdown]
# # Operational Plan
#
# The operational plan represents a preliminary exercise undertaken by the planning team to identify the potential leads, potential participants, and estimated cost for the implementation of each action in the Horsefly River watershed. The table below summarizes individuals, groups, or organizations that the planning team felt could lead or participate in the implementation of the plan and should be interpreted as the first step in on-going planning and engagement to develop more detailed and sophisticated action plans for each entry in the table. The individuals, groups, and organizations listed under the "Lead(s)" or "Potential Participants" columns are those that provisionally expressed interest in participating in one of those roles or were suggested by the planning team for further engagement (denoted in bold), for those that are not members of the planning team. The leads, participants, and estimated costs in the operational plan are not binding nor an official commitment of resources, but rather provide a roadmap for future coordination and engagement to work towards implementation of the WCRP.
#
# Table 13. Operational plan to support the implementation of strategies and actions to improve connectivity for target species in the Horsefly River watershed.

# %%
from IPython.display import display
import pandas as pd
import numpy as np

data = pd.read_csv('tables\Table13.csv', index_col=False)

data = data.replace(np.nan, '', regex=True)

display(data)
# Out:
#                                    Strategy / Actions  \
# 0                    Strategy 1: Crossing Remediation
# 1   1.1 – Remediate crossings that are acting as b...
# 2   1.2 – Lobby that the government enforce their ...
# 3   1.3 – Initiate a barrier owner outreach progra...
# 4   1.4 – Knowledge Gap: Continue updating the bar...
# 5   1.5 – Knowledge Gap: conduct field assessments...
# 6   1.6 - Update longitudinal connectivity goal if...
# 7   1.7 – Knowledge Gap: Identify and map crossing...
# 8   1.8 – Knowledge Gap: Compile road maintenance ...
# 9   1.9 – Knowledge Gap: Survey trail-stream cross...
# 10            Strategy 2: Lateral Barrier Remediation
# 11  2.1 – Remediate dikes / berms / other structur...
# 12   2.2 – Initiate a barrier owner outreach program
# 13  2.3 – Knowledge Gap: Identify and map year-rou...
# 14  2.4 – Knowledge Gap: Map lateral barriers and ...
# 15  2.5 – Knowledge Gap: Develop a framework to as...
# 16                        Strategy 3: Dam Remediation
# 17                               3.1 - Remediate Dams
# 18                         3.2 - Install Fish Passage
# 19  3.3 - Connect with Cattleman's Association to ...
# 20  3.4 - Knowledge Gap: Continue updating the bar...
# 21  3.5 - Knowledge Gap: Assess dams to determine ...
# 22  3.6 - Knowledge Gap: Identify and map dam owne...
# 23                     Strategy 4: Barrier Prevention
# 24  4.1 – Explore potential partnerships with indu...
# 25  4.2 – Stabilize sediment sources that are expl...
# 26                 Strategy 5: Progress Tracking Plan
# 27    5.1 - Implement the WCRP Progress Tracking Plan
# 28  5.2 - Develop a communication action to raise ...
# 29                                             Total:
# 30                                 Fundraising total:
# 31           Proponent/government contribution total:
# 32
# 33
# 34
#
#                        Lead(s) [1]  \
# 0
# 1                              CWF
# 2                              TBD
# 3                    HRR, CWF, DFO
# 4                              CWF
# 5                              CWF
# 6
# 7                              TBD
# 8                              DFO
# 9                             WLFN
# 10
# 11                             CWF
# 12                             TBD
# 13  Horsefly River Roundtable, DFO
# 14                             CWF
# 15                             CWF
# 16
# 17                             TBD
# 18                             TBD
# 19                             TBD
# 20                             CWF
# 21            HRR(?) DFO(?) CWF(?)
# 22                             TBD
# 23
# 24                             TBD
# 25                             TBD
# 26
# 27                             CWF
# 28                        CWF, HRR
# 29
# 30
# 31
# 32
# 33
# 34
#
#                                         Participants3    Total Budget
# 0                                                      $3,666,300.00
# 1   Horsefly River Roundtable, Fisheries and Ocean...  $3,500,000.00
# 2   CWF, Horsefly River Roundtable, Williams Lake ...     $10,000.00
# 3                                                                 TBD
# 4                                                 TBD    $100,000.00
# 5                      Horsefly River Roundtable, DFO     $50,300.00
# 6
# 7                                 CWF, DFO (Anthonie)      $1,500.00
# 8                             CWF, WLFN, DFO, FLNRORD      $2,000.00
# 9                                            CWF, DFO      $2,500.00
# 10                                                        $80,000.00
# 11                     DFO, Horsefly River Roundtable             TBD
# 12                                           CWF, DFO             TBD
# 13  CWF, Northern Shuswap Tribal Council (NSTC), WLFN     $65,000.00
# 14                     DFO, Horsefly River Roundtable      $5,000.00
# 15                                                DFO     $10,000.00
# 16                                                     $1,305,000.00
# 17                                                TBD  $1,305,000.00
# 18                                                TBD             TBD
# 19                                                TBD             TBD
# 20                                                TBD          $0.00
# 21                                                TBD             TBD
# 22                                                TBD             TBD
# 23                                                       $110,000.00
# 24          CWF, DFO, Horsefly River Roundtable, WLFN     $10,000.00
# 25                                                DFO    $100,000.00
# 26                                                                TBD
# 27                                                                TBD
# 28                                                TBD             TBD
# 29                                                     $5,161,300.00
# 30                                                        $2,508,800
# 31                                                        $2,652,500
# 32
# 33
# 34
